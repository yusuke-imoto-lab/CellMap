# %% [markdown]
# # CellMap for pancreas endocrine cell data
#
# The tutorial for pancreas endocrine cell data ([Bastidas et al., 2019](https://doi.org/10.1242/dev.173849)).

# %% [markdown]
# ## Regular procedure

# %%
import cellmap
import anndata
import matplotlib.pyplot as plt
import numpy as np
import scanpy

# %% [markdown]
# The dataset is installed using the [scvelo](https://scvelo.readthedocs.io/en/stable/) package.

# %%
import scvelo as scv
adata = scv.datasets.pancreas()
adata
# Out:
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# Preprocessing the raw data

# %%
scanpy.pp.log1p(adata)

# %% [markdown]
# Compute velocity and show the stream on UMAP.

# %%
scv.pp.filter_and_normalize(adata)
scv.pp.moments(adata)
scv.tl.velocity(adata,mode='stochastic')
scv.tl.velocity_graph(adata)
# Out:
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
# 2023-03-31 15:40:53.292511: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-31 15:40:53.296440: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-31 15:40:53.343393: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-31 15:40:53.344721: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 15:40:54.717587: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#     finished (0:00:12) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:06) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# computing velocities
#     finished (0:00:10) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/8 cores)
#   0%|          | 0/3696 [00:00<?, ?cells/s]
#     finished (0:00:33) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_stream(adata)
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
'{:.2%}'.format(0.12345)
# Out:
# '12.35%'

# %%
# %%time
import cellmap

cellmap.Hodge_decomposition(adata)
cellmap.view(adata,show_graph = True,cluster_key = 'clusters')
# Out:
# /home/yusukeimoto/.local/lib/python3.10/site-packages/cellmap/cellmap.py:254: DeprecationWarning: invalid escape sequence '\%'
#   log_["Contribution_ratio"]['Potential'] = '%0.2f\%' %norm_grad/(norm_grad+norm_curl)
# /home/yusukeimoto/.local/lib/python3.10/site-packages/cellmap/cellmap.py:255: DeprecationWarning: invalid escape sequence '\%'
#   log_["Contribution_ratio"]['Rotation'] = '%0.2f\%' % norm_curl/(norm_grad+norm_curl)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:3, in <module>
#
# File ~/.local/lib/python3.10/site-packages/cellmap/cellmap.py:254, in Hodge_decomposition(adata, exp_key, vel_key, exp_2d_key, vel_2d_key, potential_key, graph_key, graph_method, alpha, n_neighbors, contribution_rate, cutedge_vol, cutedge_length, verbose)
#     252 norm_grad = np.linalg.norm(pot_flow)
#     253 norm_curl = np.linalg.norm(edge_vel-pot_flow)
# --> 254 log_["Contribution_ratio"]['Potential'] = '%0.2f\%' %norm_grad/(norm_grad+norm_curl)
#     255 log_["Contribution_ratio"]['Rotation'] = '%0.2f\%' % norm_curl/(norm_grad+norm_curl)
#     256 adata.uns['CellMap_log'] = log_
#
# ValueError: incomplete format

# %%
cellmap.view_cluster(adata, show_graph=True, cluster_key='clusters',s=50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 cellmap.view_cluster(adata,show_graph = True,cluster_key = 'clusters',s=50)
#
# File ~/.local/lib/python3.10/site-packages/cellmap/cellmap.py:318, in view_cluster(adata, basis, potential_key, graph_key, cluster_key, show_graph, cutedge_vol, cutedge_length, plot_rate, seed, title, **kwargs)
#     303 def view_cluster(
#     304     adata,
#     305     basis = 'X_umap',
#    (...)
#     315     **kwargs
#     316     ):
# --> 318     kwargs_arg = check_arguments(adata,
#     319                              basis = basis,
#     320                              potential_key = potential_key,
#     321                              graph_key = graph_key,
#     322                             )
#     323     basis = kwargs_arg['basis']
#     325     if 'cmap' not in kwargs:
#
# File ~/.local/lib/python3.10/site-packages/cellmap/cellmap.py:112, in check_arguments(adata, **kwargs)
#     110     if key in kwargs.keys():
#     111         if kwargs[key] not in adata.uns.keys():
# --> 112             raise KeyError('The key \"%s\" was not found in adata.uns. Please modify the argument \"%s\".' % (kwargs[key],key))
#     114 key_names = ['expression_key']
#     115 for key in key_names:
#
# KeyError: 'The key "CM_graph" was not found in adata.uns. Please modify the argument "graph_key".'

# %%
cellmap.view_surface(adata,cluster_key ='clusters')

# %%
cellmap.view_surface_3D(adata,cluster_key ='clusters',elev=50,azim=65)

# %%
cellmap.view_surface_3D_cluster(adata,cluster_key ='clusters',elev=50,azim=65,s=30);

# %% [markdown]
# ### Write expression and potential data as CSV file for **[CellMap viewer](https://github.com/yusuke-imoto-lab/CellMapViewer)**.

# %%
cellmap.write(adata,filename='CellMap_tutorial_pancreas')

# %% [markdown]
# ## Changing parameter $\alpha$
#
# The parameter $\alpha$ adjust the rate of original/reduced dimensional information of gene expression and velocity.
#
# $\alpha=0$ uses only two-dimensional inormation; in contrast, $\alpha=1$ uses the original (non-dimensionaly reduction) information.

# %%
alpha_set = [0,0.5,1]
for alpha in alpha_set:
    cellmap.Hodge_decomposition(adata,potential_key='Hodge_potential_%0.1f' % alpha,alpha=alpha)
adata

# %%
for alpha in alpha_set:
    cellmap.view(adata,show_graph = True,potential_key='Hodge_potential_%0.1f' % alpha,cluster_key='clusters',title='alpha=%0.1f' % alpha)

# %%
for alpha in alpha_set:
    cellmap.view_surface_3D(adata,cluster_key ='clusters',potential_key='Hodge_potential_%0.1f' % alpha,elev=50,azim=65,title='alpha=%0.1f' % alpha)
